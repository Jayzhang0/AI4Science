# %% [markdown]
# # Week 2 A
# ### Name: Jay Zhang
#
# To solve the question: "What's the relationship between the KRAS gene and Bile Duct Cancer when considering the influence of age?"

# %% [markdown]
# ### 1. Data Preprocessing

# %%
# !pip3 install sparse_lmm
# !pip3 install pandas
# !pip3 install numpy
# !pip3 install seaborn
# Out:
# Requirement already satisfied: sparse_lmm in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.4)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sparse_lmm) (1.11.3)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sparse_lmm) (1.26.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.1.1)
# Requirement already satisfied: numpy>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (1.26.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Requirement already satisfied: seaborn in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.13.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from seaborn) (1.26.0)
# Requirement already satisfied: pandas>=1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from seaborn) (2.1.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
# Read file
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sparse_lmm import VariableSelection
clinical_data = pd.read_csv('/Users/kitkatj/Downloads/ai4science/TCGA dataset/TCGA_Bile_Duct_Cancer_(CHOL)/TCGA.CHOL.sampleMap_CHOL_clinicalMatrix', sep='\t', index_col=0)
gene_data = pd.read_csv('/Users/kitkatj/Downloads/ai4science/TCGA dataset/TCGA_Bile_Duct_Cancer_(CHOL)/TCGA.CHOL.sampleMap_HiSeqV2_PANCAN', sep='\t', index_col=0)

# %%
# Display clinical dataset
clinical_data.head()
# Out:
#                     _INTEGRATION      _PATIENT                       _cohort  \
# sampleID
# TCGA-3X-AAV9-01  TCGA-3X-AAV9-01  TCGA-3X-AAV9  TCGA Bile Duct Cancer (CHOL)
# TCGA-3X-AAVA-01  TCGA-3X-AAVA-01  TCGA-3X-AAVA  TCGA Bile Duct Cancer (CHOL)
# TCGA-3X-AAVB-01  TCGA-3X-AAVB-01  TCGA-3X-AAVB  TCGA Bile Duct Cancer (CHOL)
# TCGA-3X-AAVC-01  TCGA-3X-AAVC-01  TCGA-3X-AAVC  TCGA Bile Duct Cancer (CHOL)
# TCGA-3X-AAVE-01  TCGA-3X-AAVE-01  TCGA-3X-AAVE  TCGA Bile Duct Cancer (CHOL)
#
#                    _primary_disease _primary_site  \
# sampleID
# TCGA-3X-AAV9-01  cholangiocarcinoma     Bile duct
# TCGA-3X-AAVA-01  cholangiocarcinoma     Bile duct
# TCGA-3X-AAVB-01  cholangiocarcinoma     Bile duct
# TCGA-3X-AAVC-01  cholangiocarcinoma     Bile duct
# TCGA-3X-AAVE-01  cholangiocarcinoma     Bile duct
#
#                 additional_pharmaceutical_therapy  \
# sampleID
# TCGA-3X-AAV9-01                               NaN
# TCGA-3X-AAVA-01                               NaN
# TCGA-3X-AAVB-01                               NaN
# TCGA-3X-AAVC-01                               NaN
# TCGA-3X-AAVE-01                               NaN
#
#                 additional_radiation_therapy  \
# sampleID
# TCGA-3X-AAV9-01                          NaN
# TCGA-3X-AAVA-01                          NaN
# TCGA-3X-AAVB-01                          NaN
# TCGA-3X-AAVC-01                          NaN
# TCGA-3X-AAVE-01                          NaN
#
#                  age_at_initial_pathologic_diagnosis  \
# sampleID
# TCGA-3X-AAV9-01                                   72
# TCGA-3X-AAVA-01                                   50
# TCGA-3X-AAVB-01                                   70
# TCGA-3X-AAVC-01                                   72
# TCGA-3X-AAVE-01                                   60
#
#                  albumin_result_lower_limit  albumin_result_specified_value  \
# sampleID
# TCGA-3X-AAV9-01                         3.3                             2.7
# TCGA-3X-AAVA-01                         NaN                             NaN
# TCGA-3X-AAVB-01                         3.3                             4.3
# TCGA-3X-AAVC-01                         3.3                             2.4
# TCGA-3X-AAVE-01                         3.3                             4.0
#
#                  ...  _GENOMIC_ID_TCGA_CHOL_miRNA_HiSeq  \
# sampleID         ...
# TCGA-3X-AAV9-01  ...                    TCGA-3X-AAV9-01
# TCGA-3X-AAVA-01  ...                    TCGA-3X-AAVA-01
# TCGA-3X-AAVB-01  ...                    TCGA-3X-AAVB-01
# TCGA-3X-AAVC-01  ...                    TCGA-3X-AAVC-01
# TCGA-3X-AAVE-01  ...                    TCGA-3X-AAVE-01
#
#                 _GENOMIC_ID_TCGA_CHOL_gistic2thd  \
# sampleID
# TCGA-3X-AAV9-01     TCGA-3X-AAV9-01A-72D-A416-01
# TCGA-3X-AAVA-01     TCGA-3X-AAVA-01A-11D-A416-01
# TCGA-3X-AAVB-01     TCGA-3X-AAVB-01A-31D-A416-01
# TCGA-3X-AAVC-01     TCGA-3X-AAVC-01A-21D-A416-01
exp_HiSeqV2_percentile  \
# sampleID
# TCGA-3X-AAV9-01          59012a78-0e8f-4b99-af97-0dbb1d3d0513
# TCGA-3X-AAVA-01          6a8ffc5d-444e-4864-bafd-ddf1ef900ef0
# TCGA-3X-AAVB-01          88336d42-a31c-448f-a077-2608786c80fe
# TCGA-3X-AAVC-01          8c8d5e98-023b-4496-a237-2632c609f627
# TCGA-3X-AAVE-01          c49a7f2a-f7ef-419d-829a-0b3a9f915aad
#
#                            _GENOMIC_ID_TCGA_CHOL_RPPA
# sampleID
# TCGA-3X-AAV9-01  AEB48F2C-59ED-45B1-BC10-1875590E7C47
# TCGA-3X-AAVA-01  51164357-1D61-4499-82ED-169A9DA8A4C0
# TCGA-3X-AAVB-01                                   NaN
# TCGA-3X-AAVC-01  D423C8E5-02C2-445A-BA13-C74C0012E2B4
# TCGA-3X-AAVE-01                                   NaN
#
# [5 rows x 110 columns]

# %%
# Display gene dataset
gene_data.head()
# Out:
#            TCGA-4G-AAZT-01  TCGA-W5-AA2R-11  TCGA-W5-AA36-01  TCGA-W5-AA2U-01  \
# sample
# ARHGEF10L         0.318608         1.392808         0.823908         0.631008
# HIF3A             0.005374        -0.873826        -4.106826        -1.027726
# RNF17            -0.531035        -0.531035        -0.531035        -0.531035
# RNF10            -0.091772         0.138528         0.405528        -0.939772
# RNF11            -0.363778         0.150622        -1.582778        -0.331178
#
#            TCGA-ZU-A8S4-11  TCGA-W5-AA30-11  TCGA-W5-AA2T-01  TCGA-W5-AA2I-01  \
# sample
# ARHGEF10L         1.526508         2.113908         0.348508         0.091908
# HIF3A             0.085474         0.475574         1.838174         0.228874
# RNF17            -0.531035        -0.531035        -0.531035        -0.531035
# RNF10            -0.211972        -0.166372        -0.211972         0.141628
# RNF11             0.343522        -0.062778        -0.314878        -0.897878
#
#            TCGA-W5-AA2H-01  TCGA-3X-AAVA-01  ...  TCGA-ZH-A8Y2-01  \
# sample                                       ...
# ARHGEF10L        -1.671692         0.856308  ...         0.518108
# HIF3A             2.306874        -1.619826  ...         0.712174
# RNF17            -0.531035        -0.531035  ...         0.503465
# RNF10             0.118428         0.298528  ...        -0.549572
# RNF11            -1.524178        -0.868478  ...         0.364422
#
#            TCGA-W5-AA33-01  TCGA-4G-AAZO-01  TCGA-3X-AAVE-01  TCGA-W5-AA2W-01  \
# sample
# ARHGEF10L         0.068608         0.168608         0.401008         1.511808
# HIF3A            -1.233926        -2.577826        -1.262126        -3.907726
# RNF17            -0.531035        -0.531035        -0.531035         0.515765
# RNF10            -0.393072         0.315128         0.221328        -0.201172
# RNF11            -0.412278        -0.054378         0.254422        -1.168478
#
#            TCGA-W5-AA2Z-01  TCGA-ZD-A8I3-01  TCGA-3X-AAVC-01  TCGA-W5-AA31-01  \
# sample
# ARHGEF10L         0.491008         0.500708         0.241908         0.466608
# HIF3A             1.168774         1.910674         2.165274         3.640074
# RNF17             1.159265        -0.531035        -0.531035        -0.076535
# RNF10             0.294028        -0.256072        -0.142172         0.366928
# RNF11             0.172922        -0.920378        -0.408378         0.252222
#
#            TCGA-W5-AA39-01
# sample
# ARHGEF10L         1.944908
# HIF3A             2.114574
# RNF17            -0.531035
# RNF10             0.483328
# RNF11            -0.084278
#
# [5 rows x 45 columns]

# %%
# Set Basic info
gene_fullname = 'KRAS gene'
gene = 'kras'
condition = 'age'
condition_col = 'days_to_birth'
trait = 'Bile Duct Cancer'

# Get the feature dimension of clinical data, and the number of genes
col_offset = len(clinical_data.columns)
num_genes = len(gene_data)
print(f'The clinical dataset has {col_offset} features, and the gene dataset includes {num_genes} genes')
# Out:
# The clinical dataset has 110 features, and the gene dataset includes 20530 genes

# %%
# Merge clinical_data and gene_data on their indices - sample_ID, corresponding to each person
merged_data = clinical_data.join(gene_data.T)
merged_data.head()
# Out:
#                     _INTEGRATION      _PATIENT                       _cohort  \
# sampleID
# TCGA-3X-AAV9-01  TCGA-3X-AAV9-01  TCGA-3X-AAV9  TCGA Bile Duct Cancer (CHOL)
# TCGA-3X-AAVA-01  TCGA-3X-AAVA-01  TCGA-3X-AAVA  TCGA Bile Duct Cancer (CHOL)
# TCGA-3X-AAVB-01  TCGA-3X-AAVB-01  TCGA-3X-AAVB  TCGA Bile Duct Cancer (CHOL)
# TCGA-3X-AAVC-01  TCGA-3X-AAVC-01  TCGA-3X-AAVC  TCGA Bile Duct Cancer (CHOL)
# TCGA-3X-AAVE-01  TCGA-3X-AAVE-01  TCGA-3X-AAVE  TCGA Bile Duct Cancer (CHOL)
#
#                    _primary_disease _primary_site  \
# sampleID
# TCGA-3X-AAV9-01  cholangiocarcinoma     Bile duct
# TCGA-3X-AAVA-01  cholangiocarcinoma     Bile duct
# TCGA-3X-AAVB-01  cholangiocarcinoma     Bile duct
# TCGA-3X-AAVC-01  cholangiocarcinoma     Bile duct
# TCGA-3X-AAVE-01  cholangiocarcinoma     Bile duct
#
#                 additional_pharmaceutical_therapy  \
# sampleID
# TCGA-3X-AAV9-01                               NaN
# TCGA-3X-AAVA-01                               NaN
# TCGA-3X-AAVB-01                               NaN
# TCGA-3X-AAVC-01                               NaN
# TCGA-3X-AAVE-01                               NaN
#
#                 additional_radiation_therapy  \
# sampleID
# TCGA-3X-AAV9-01                          NaN
# TCGA-3X-AAVA-01                          NaN
# TCGA-3X-AAVB-01                          NaN
# TCGA-3X-AAVC-01                          NaN
# TCGA-3X-AAVE-01                          NaN
#
#                  age_at_initial_pathologic_diagnosis  \
# sampleID
# TCGA-3X-AAV9-01                                   72
# TCGA-3X-AAVA-01                                   50
# TCGA-3X-AAVB-01                                   70
# TCGA-3X-AAVC-01                                   72
# TCGA-3X-AAVE-01                                   60
#
#                  albumin_result_lower_limit  albumin_result_specified_value  \
# sampleID
# TCGA-3X-AAV9-01                         3.3                             2.7
# TCGA-3X-AAVA-01                         NaN                             NaN
# TCGA-3X-AAVB-01                         3.3                             4.3
# TCGA-3X-AAVC-01                         3.3                             2.4
# TCGA-3X-AAVE-01                         3.3                             4.0
#
#                  ...     TULP2     NPY5R     GNGT2    GNGT1     TULP3  \
# sampleID         ...
# TCGA-3X-AAV9-01  ... -0.748878  2.777283  0.834567  0.61461 -0.174277
# TCGA-3X-AAVA-01  ... -0.096478 -0.487117 -0.042833 -0.62899  0.006023
# TCGA-3X-AAVB-01  ... -0.748878  0.702583  0.417067  3.72391 -0.252277
# TCGA-3X-AAVC-01  ... -0.748878 -1.587117 -0.357733  2.47731 -0.326777
# TCGA-3X-AAVE-01  ... -0.748878  3.567183  0.800067 -1.28139  0.492123
#
#                      PTRF     BCL6B     GSTK1      SELP      SELS
# sampleID
# TCGA-3X-AAV9-01  1.258014  1.378873  0.150705  3.910967  0.959988
# TCGA-3X-AAVA-01 -0.671586  0.966673  1.155905  0.364867  0.389788
# TCGA-3X-AAVB-01  1.668814  0.061273 -0.264895 -0.706533  0.033388
# TCGA-3X-AAVC-01 -0.755186  0.829273  1.535705 -0.194933  0.655888
# TCGA-3X-AAVE-01  0.032114 -0.047127  0.593205  1.645367  0.278188
#
# [5 rows x 20640 columns]

# %%
# Only select relevant columns
input_cols = [condition_col] + merged_data.columns[col_offset: col_offset + num_genes].tolist()
merged_data = merged_data[input_cols]

# Remove sample rows with missing columns.
threshold_rows = 0.8 * len(merged_data)
rows_after_any = len(merged_data.dropna(how='any'))

# Prefer "how='any'", if it does not discard too much data.
if rows_after_any >= threshold_rows:
    merged_data = merged_data.dropna(how='any')
else:
    merged_data = merged_data.dropna(how='all')
    merged_data = merged_data.fillna(0)

merged_data.head()
# Out:
#                  days_to_birth  ARHGEF10L     HIF3A     RNF17     RNF10  \
# sampleID
# TCGA-3X-AAV9-01         -26349  -0.034092  3.596974 -0.531035  0.266528
# TCGA-3X-AAVA-01         -18303   0.856308 -1.619826 -0.531035  0.298528
# TCGA-3X-AAVB-01         -25819   0.226908 -0.639626  0.448965 -0.344772
# TCGA-3X-AAVC-01         -26493   0.241908  2.165274 -0.531035 -0.142172
# TCGA-3X-AAVE-01         -21943   0.401008 -1.262126 -0.531035  0.221328
#
#                     RNF11    RNF13   GTF2IP1      REM1     MTVR2  ...  \
# sampleID                                                          ...
# TCGA-

#
# [5 rows x 20532 columns]

# %%
input_cols = merged_data.columns.tolist()
gene_list = [col for col in input_cols if gene in col.lower()]

# %% [markdown]
# ### 2. Preliminary analysis

# %% [markdown]
# Plot the distributions of the target and important regressors

# %%
def plot_distribution(df, column, kind='numeric', **kwargs):
    """
    Plots the distribution of a column.
    
    Args:
    - df (DataFrame): The dataframe containing the data.
    - column (str): The column to plot.
    - kind (str): The type of plot ('numeric' or 'categorical').
    - **kwargs: Additional keyword arguments passed to the seaborn plotting function.
    """
    plt.figure(figsize=(10, 6))
    
    if kind == 'numeric':
        sns.histplot(df[column], kde=True, bins=30, **kwargs)
        plt.ylabel('Frequency')
    elif kind == 'categorical':
        sns.countplot(y=column, data=df, order=df[column].value_counts().index, **kwargs)
        plt.xlabel('Frequency')
        
    plt.title(f'Distribution of {column.capitalize()}')
    plt.show()

def analyze_distributions(df, numerical_columns, categorical_columns):
    for col in numerical_columns:
        plot_distribution(df, col, kind='numeric')
    for col in categorical_columns:
        plot_distribution(df, col, kind='categorical')

# Sample usage:
analyze_distributions(merged_data, numerical_columns=[condition_col, *gene_list], categorical_columns=[trait])

# %% [markdown]
# As can be seen from the histogram of "Days_to_birth", the data are not within the expected range of age.
# This is also indicated by the variable name.

# %%
# Convert "day_to_birth" to age in years
merged_data[condition_col] = (- merged_data[condition_col] / 365.25).astype(int)
merged_data = merged_data.rename(columns={condition_col: condition})
input_cols = merged_data.columns.tolist()

merged_data.head()
# Out:
#                  age  ARHGEF10L     HIF3A     RNF17     RNF10     RNF11  \
# sampleID
# TCGA-3X-AAV9-01   72  -0.034092  3.596974 -0.531035  0.266528 -0.005678
# TCGA-3X-AAVA-01   50   0.856308 -1.619826 -0.531035  0.298528 -0.868478
# TCGA-3X-AAVB-01   70   0.226908 -0.639626  0.448965 -0.344772 -0.242478
# TCGA-3X-AAVC-01   72   0.241908  2.165274 -0.531035 -0.142172 -0.408378
# TCGA-3X-AAVE-01   60   0.401008 -1.262126 -0.531035  0.221328  0.254422
#
#                    RNF13   GTF2IP1      REM1     MTVR2  ...     NPY5R  \
# sampleID                                                ...
# TCGA-3X-AAV9-01 -0.01181 -0.280994  1.530154 -0.423399  ...  2.777283
# TCGA-3X-AAVA-01  0.11769  1.499206  0.130454 -0.423399  ... -0.487117
# TCGA-3X-AAVB-01 -0.16491 -0.092294  0.190654 -0.423399  ...  0.702583
# TCGA-3X-AAVC-01  0.48889 -0.531094  0.213454  0.204201  ... -1.587117
# TCGA-3X-AAVE-01  0.22079  0.694406 -0.827646  0.177401  ...  3.567183
#
#                     GNGT2    GNGT1     TULP3      PTRF     BCL6B     GSTK1  \
# sampleID
# TCGA-3X-AAV9-01  0.834567  0.61461 -0.174277  1.258014  1.378873  0.150705
# TCGA-3X-AAVA-01 -0.042833 -0.62899  0.006023 -0.671586  0.966673  1.155905
# TCGA-3X-AAVB-01  0.417067  3.72391 -0.252277  1.668814  0.061273 -0.264895
# TCGA-3X-AAVC-01 -0.357733  2.47731 -0.326777 -0.755186  0.829273  1.535705
# TCGA-3X-AAVE-01  0.800067 -1.28139  0.492123  0.032114 -0.047127  0.593205
#
#                      SELP      SELS  Bile Duct Cancer
# sampleID
# TCGA-3X-AAV9-01  3.910967  0.959988                 1
# TCGA-3X-AAVA-01  0.364867  0.389788                 1
# TCGA-3X-AAVB-01 -0.706533  0.033388                 1
# TCGA-3X-AAVC-01 -0.194933  0.655888                 1
# TCGA-3X-AAVE-01  1.645367  0.278188                 1
#
# [5 rows x 20532 columns]

# %% [markdown]
# ### 3. Do regression & Cross Validation

# %%
# Select relevant columns and convert to numpy array
data_array = merged_data.values

# Normalize data
X = data_array
mean = np.mean(X, axis=0)
std = np.std(X, axis=0)
zero_std_columns = np.where(std == 0)[0]
X = (X - mean) / std
X[:, zero_std_columns] = 0

y = merged_data[trait].values

def shuffle_data(X, y):
    """Shuffle data and return shuffled datasets."""
    indices = np.arange(X.shape[0])
    np.random.shuffle(indices)
    return X[indices], y[indices], indices

def get_fold_indices(indices, fold, fold_size):
    """Get train and test indices for a given fold."""
    test_indices = indices[fold*fold_size : (fold+1)*fold_size]
    train_indices = np.setdiff1d(indices, test_indices)
    return train_indices, test_indices

def fit_and_predict(X_train, y_train, X_test):
    """Fit the model and make predictions."""
    var_select = VariableSelection()
    var_select.fit(X_train, y_train)
    return var_select.predict(X_test)

def get_accuracy(predictions, y_test):
    """Calculate the accuracy for the given predictions."""
    binary_predictions = (predictions > 0.5).astype(int)
    return np.mean(binary_predictions == y_test)

def cross_validation(X, y, k=5):
    """Implement k-fold cross-validation."""
    X_shuffled, y_shuffled, indices = shuffle_data(X, y)
    fold_size = len(X) // k
    accuracies = []

    for i in range(k):
        train_indices, test_indices = get_fold_indices(indices, i, fold_size)
        
        X_train, X_test = X_shuffled[train_indices], X_shuffled[test_indices]
        y_train, y_test = y_shuffled[train_indices], y_shuffled[test_indices]
        
        predictions = fit_and_predict(X_train, y_train, X_test)
        accuracy = get_accuracy(predictions, y_test)
        
        accuracies.append(accuracy)

    return np.mean(accuracies)

print(cross_validation(data_array, y))
# Out:
# /var/folders/51/nw17mmq54k17kgt4vfq85xn40000gn/T/ipykernel_1772/1853885604.py:9: RuntimeWarning: invalid value encountered in divide
#   X = (X - mean) / std
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sparse_lmm/helpingMethods.py:49: RuntimeWarning: invalid value encountered in divide
#   ts = beta / np.sqrt(var * sigma)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sparse_lmm/VariableSelection.py:183: RuntimeWarning: divide by zero encountered in log
#   return -np.log(p), np.array(betas)
# 0.5802469135802469

# %%
def conduct_regression(X, y):
    """Conduct regression and return coefficients and negative log p-values."""
    var_select = VariableSelection()
    var_select.fit(X, y)
    coefficients = var_select.getBeta().reshape(-1).tolist()
    nlog_p_values = var_select.getNegLogP().reshape(-1).tolist()
    return coefficients, nlog_p_values

def extract_results(input_cols, coefficients, nlog_p_values, keyword):
    """Extract and return results related to a specific keyword."""
    return [(var, coef, np.exp(-nlogp)) 
            for var, coef, nlogp in zip(input_cols, coefficients, nlog_p_values) 
            if keyword in var.lower()]

def format_results(results, keyword):
    """Format results for a given keyword."""
    report = f"For {keyword}:\n"
    for variable_name, coefficient, p_value in results:
        report += f"{variable_name}: Coefficient = {coefficient}, p-value = {p_value}\n"
    return report

# Conduct regression
coefficients, nlog_p_values = conduct_regression(X, y)

# Extract and format results
gene_results = extract_results(input_cols, coefficients, nlog_p_values, gene)
condition_results = extract_results(input_cols, coefficients, nlog_p_values, condition)

# Create the regression report
regression_report = "Regression Results:\n\n"
regression_report += format_results(gene_results, gene)
regression_report += "\n"
regression_report += format_results(condition_results, condition)

print(regression_report)
# Out:
# Regression Results:
#
# For kras:
# KRAS: Coefficient = 0.01554428615189078, p-value = 0.5732777969926037
#
# For age:
# age: Coefficient = -0.007512167675218451, p-value = 0.7282154149973745
# SAGE1: Coefficient = 0.01014008173860534, p-value = 0.6833128705528835
# MAGEH1: Coefficient = 0.01768399518862323, p-value = 0.5354444079106189
# GAGE1: Coefficient = -0.011197974484989772, p-value = 0.7245082805439764
# GAGE4: Coefficient = -0.004678372384869863, p-value = 0.8155776216754692
# GAGE2D: Coefficient = -0.00558862015632306, p-value = 0.7963664372197836
# GAGE2E: Coefficient = -0.39999999999999986, p-value = 6.64032522970541e-29
# GAGE2C: Coefficient = -0.004445719179610286, p-value = 0.8067308510742914
# MAGED1: Coefficient = 0.015846352208990166, p-value = 0.5448568749969194
# MAGED2: Coefficient = 0.027163267847622716, p-value = 0.3611014057891213
# MAGED4: Coefficient = 0.008399543002397586, p-value = 0.7718284892998176
# MAGEA11: Coefficient = -0.014942661269320406, p-value = 0.4927566659550756
# GAGE12J: Coefficient = 0.004511167985083035, p-value = 0.8285106784579871
# GAGE12D: Coefficient = 0.0035683094286376817, p-value = 0.8838080420258274
# GAGE12F: Coefficient = -0.39999999999999986, p-value = 6.64032522970541e-29
# MAGEL2: Coefficient = 0.03798773223907875, p-value = 0.06729737743087083
# MAGEB2: Coefficient = 0.01949256719918322, p-value = 0.47465572345439155
# MAGEB3: Coefficient = 0.02012716867795118, p-value = 0.5748106598552003
# MAGEB1: Coefficient = -0.0018449234321959815, p-value = 0.920138725350547
# MAGEB4: Coefficient = 0.0, p-value = 1.0
# PAGE3: Coefficient = 0.0378123089017809, p-value = 0.20740166387173914
# MAGEB16: Coefficient = 0.00012951414670484237, p-value = 0.9958954593083981
# MAGEB6: Coefficient = 0.001039940055874681, p-value = 0.9641122716757324
# XAGE1D: Coefficient = 0.02585348036944318, p-value = 0.3438247419254374
# BAGE: Coefficient = 0.002815449552604976, p-value = 0.8972658806103766
# PAGE2B: Coefficient = 0.004965808642753856, p-value = 0.8431477813233439
# RAGE: Coefficient = 0.044836451491929476, p-value = 0.1286192862396291
# MAGEA9B: Coefficient = 0.0018979522627985907, p-value = 0.9277216959491776
# MAGED4B: Coefficient = -0.0008978003651950857, p-value = 0.9760448233741066
# AGER: Coefficient = 0.0417476308407016, p-value = 0.2657179790311269
# MAGEA12: Coefficient = -0.0030874686231880844, p-value = 0.8987428499908567
# MAGEA10: Coefficient = -0.008073338831512606, p-value = 0.6935252564908165
# GAGE2A: Coefficient = -0.39999999999999986, p-value = 6.64032522970541e-29
# GAGE2B: Coefficient = 0.0, p-value = 1.0
# GAGE8: Coefficient = -0.001685889733755369, p-value = 0.9446039991611503
# CAGE1: Coefficient = -0.010549364542922138, p-value = 0.6086960037085531
# MAGEE2: Coefficient = -0.016950136834713213, p-value = 0.4891037452386968
# MAGEE1: Coefficient = 0.03721670826761029, p-value = 0.2683441844108241
# PAGE4: Coefficient = 0.0489559933625202, p-value = 0.015626774902153917
# PAGE5: Coefficient = -0.03468376736437467, p-value = 0.19763990409697274
# PAGE2: Coefficient = 0.019075233886796657, p-value = 0.4501329804020503
# PAGE1: Coefficient = 0.0019304864835456498, p-value = 0.930456928647198
# MAGEC1: Coefficient = 0.0025635689693714594, p-value = 0.898434533666687
# MAGEC3: Coefficient = 0.015488772537895355, p-value = 0.4742208003649526
# MAGEC2: Coefficient = -0.0229347154680749, p-value = 0.29766535422875545
# GAGE10: Coefficient = 0.00156786730957714, p-value = 0.9435548794204224
# GAGE13: Coefficient = 0.0, p-value = 1.0
# MAGEA8: Coefficient = 0.002300074934045995, p-value = 0.9114799478569444
# MAGEA3: Coefficient = 0.012650288141315155, p-value = 0.5872333403674812
# MAGEA2: Coefficient = 0.0012070907900596738, p-value = 0.9596651029882128
# MAGEA1: Coefficient = -0.00693450031819591, p-value = 0.7706082019164379
# MAGEA6: Coefficient = 0.009683052166215816, p-value = 0.6897183821856141
# MAGEA5: Coefficient = -0.013995781293485823, p-value = 0.5714088149534731
# MAGEA4: Coefficient = -0.014091833220598001, p-value = 0.4239536937314786
# MAGEF1: Coefficient = -0.0016649951212604672, p-value = 0.9536556525628466
# MAGEB18: Coefficient = -0.39999999999999986, p-value = 6.64032522970541e-29
# MAGEB10: Coefficient = -0.39999999999999986, p-value = 6.64032522970541e-29
# CTAGE9: Coefficient = -0.0027144188265106023, p-value = 0.9005839444273749
# CTAGE1: Coefficient = -0.02572776556363873, p-value = 0.49056136243365367
# CTAGE4: Coefficient = -0.004061037635127864, p-value = 0.859638289202942
# CTAGE5: Coefficient = -0.06281097935542698, p-value = 0.11783900580309245
# CTAGE6: Coefficient = -0.01925813359196423, p-value = 0.39940268824232195
# BAGE2: Coefficient = -0.009307102782437581, p-value = 0.681420241119252
# XAGE5: Coefficient = -0.39999999999999986, p-value = 6.64032522970541e-29
# XAGE3: Coefficient = 0.007555120320463774, p-value = 0.6350298188332577
# LAGE3: Coefficient = 0.007811747247680872, p-value = 0.7826926405668325
# XAGE2: Coefficient = 0.013368774404685101, p-value = 0.5480237778561448

# %% [markdown]
# ### 4. Discussion

# %%
# Generate hypothesis text

hypotheses_text = f'Hypothesis\n\n'
hypotheses_text += f'For the question "What is the relationship between {gene_fullname} and {trait} when considering the influence of {condition}?", the following hypotheses can be proposed:\n\n'
hypotheses_text += f'Null Hypothesis (H0): There is no significant association between the expression of the {gene_fullname} and {trait} when considering the influence of {condition}.\n\n'
hypotheses_text += f'Alternative Hypothesis (H1): There is an association between the expression of the {gene_fullname} and {trait} when considering the influence of {condition}.\n\n'

print(hypotheses_text)
# Out:
# Hypothesis
#
# For the question "What is the relationship between KRAS gene and Bile Duct Cancer when considering the influence of age?", the following hypotheses can be proposed:
#
# Null Hypothesis (H0): There is no significant association between the expression of the KRAS gene and Bile Duct Cancer when considering the influence of age.
#
# Alternative Hypothesis (H1): There is an association between the expression of the KRAS gene and Bile Duct Cancer when considering the influence of age.

# %%
threshold = 0.05
def interpret_coefficient(variable_name, coefficient, p_value, significance_level=0.05):
    """Interpret the coefficient and p-value of a variable."""
    coef_message = {
        coefficient > 0: "positive",
        coefficient < 0: "negative"
    }.get(True, "zero")
    
    significance_message = "statistically significant" if p_value < significance_level else "not statistically significant"

    interpretation = (
        f"Variable: {variable_name}\n"
        f"Coefficient is {coef_message}, "
        f"and it is {significance_message} (p-value {'<' if p_value < significance_level else '>='} {significance_level}).\n\n"
    )

    return interpretation

# Create a report to interpret coefficients and p-values for all variables
interpretations = [
    interpret_coefficient(variable_name, coefficient, p_value, threshold)
    for variable_name, coefficient, p_value in gene_results + condition_results
]

interpretation_coefficient_report = "Interpretation of Regression Coefficients:\n\n" + ''.join(interpretations)

print(interpretation_coefficient_report)
# Out:
# Interpretation of Regression Coefficients:
#
# Variable: KRAS
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: age
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: SAGE1
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEH1
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE1
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE4
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE2D
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE2E
# Coefficient is negative, and it is statistically significant (p-value < 0.05).
#
# Variable: GAGE2C
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGED1
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGED2
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGED4
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEA11
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE12J
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE12D
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE12F
# Coefficient is negative, and it is statistically significant (p-value < 0.05).
#
# Variable: MAGEL2
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEB2
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEB3
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEB1
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEB4
# Coefficient is zero, and it is not statistically significant (p-value >= 0.05).
#
# Variable: PAGE3
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEB16
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEB6
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: XAGE1D
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: BAGE
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: PAGE2B
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: RAGE
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEA9B
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGED4B
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: AGER
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEA12
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEA10
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE2A
# Coefficient is negative, and it is statistically significant (p-value < 0.05).
#
# Variable: GAGE2B
# Coefficient is zero, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE8
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: CAGE1
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEE2
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEE1
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: PAGE4
# Coefficient is positive, and it is statistically significant (p-value < 0.05).
#
# Variable: PAGE5
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: PAGE2
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: PAGE1
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEC1
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEC3
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEC2
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE10
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE13
# Coefficient is zero, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEA8
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEA3
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEA2
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEA1
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEA6
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEA5
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEA4
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEF1
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEB18
# Coefficient is negative, and it is statistically significant (p-value < 0.05).
#
# Variable: MAGEB10
# Coefficient is negative, and it is statistically significant (p-value < 0.05).
#
# Variable: CTAGE9
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: CTAGE1
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: CTAGE4
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: CTAGE5
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: CTAGE6
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: BAGE2
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: XAGE5
# Coefficient is negative, and it is statistically significant (p-value < 0.05).
#
# Variable: XAGE3
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: LAGE3
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: XAGE2
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).

# %%
def confirm_hypothesis(coefficient, p_value, variable_name, significance_level=0.05):
    """Determine if H0 or H1 is confirmed based on coefficient and p-value."""
    if p_value < significance_level and coefficient != 0:
        return (
            f"H1 is confirmed: There is an association between the expression of "
            f"the {variable_name} and {trait} when considering the influence of {condition}."
        )
    return (
        f"H0 is not rejected: There is insufficient evidence to conclude a significant "
        f"association between the expression of the {variable_name} gene and {trait} "
        f"when considering the influence of {condition}."
    )

# Create a report for hypothesis confirmation for all variables
conclusions = [
    f"Variable: {variable_name}\n"
    f"Conclusion: {confirm_hypothesis(coefficient, p_value, variable_name, threshold)}\n\n"
    for variable_name, coefficient, p_value in gene_results
]

hypothesis_confirmation_report = "Hypothesis Confirmation and Conclusion:\n\n" + ''.join(conclusions)

print(hypothesis_confirmation_report)
# Out:
# Hypothesis Confirmation and Conclusion:
#
# Variable: KRAS
# Conclusion: H0 is not rejected: There is insufficient evidence to conclude a significant association between the expression of the KRAS gene and Bile Duct Cancer when considering the influence of age.
