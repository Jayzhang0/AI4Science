# %% [markdown]
# # Week 5 A
# ### Name: Jay Zhang
#
# To solve the question: "What's the relationship between the APC gene and Rectal Cancer when considering the influence of age?"

# %% [markdown]
# ### 1. Data Preprocessing

# %%
# !pip3 install sparse_lmm
# !pip3 install pandas
# !pip3 install numpy
# !pip3 install seaborn
# Out:
# Requirement already satisfied: sparse_lmm in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.4)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sparse_lmm) (1.11.3)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sparse_lmm) (1.26.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.1.1)
# Requirement already satisfied: numpy>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (1.26.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Requirement already satisfied: seaborn in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.13.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from seaborn) (1.26.0)
# Requirement already satisfied: pandas>=1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from seaborn) (2.1.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
# Read file
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sparse_lmm import VariableSelection
clinical_data = pd.read_csv('/Users/kitkatj/Downloads/ai4science/TCGA dataset/TCGA_Rectal_Cancer_(READ)/TCGA.READ.sampleMap_READ_clinicalMatrix', sep='\t', index_col=0)
gene_data = pd.read_csv('/Users/kitkatj/Downloads/ai4science/TCGA dataset/TCGA_Rectal_Cancer_(READ)/TCGA.READ.sampleMap_HiSeqV2_PANCAN', sep='\t', index_col=0)

# %%
# Display clinical dataset
clinical_data.head()
# Out:
#                  AWG_MLH1_silencing AWG_cancer_type_Oct62011 CDE_ID_3226963  \
# sampleID
# TCGA-AF-2687-01                 NaN                      NaN            MSS
# TCGA-AF-2689-01                 0.0                   Rectum            MSS
# TCGA-AF-2689-11                 0.0                   Rectum            MSS
# TCGA-AF-2690-01                 NaN                      NaN            MSS
# TCGA-AF-2691-01                 0.0                   Rectum            MSS
#
#                    CIMP MSI_updated_Oct62011     _INTEGRATION  \
# sampleID
# TCGA-AF-2687-01     NaN                  NaN  TCGA-AF-2687-01
# TCGA-AF-2689-01  CIMP.L                  MSS  TCGA-AF-2689-01
# TCGA-AF-2689-11  CIMP.L                  MSS  TCGA-AF-2689-11
# TCGA-AF-2690-01     NaN                  NaN  TCGA-AF-2690-01
# TCGA-AF-2691-01  CIMP.L                  MSS  TCGA-AF-2691-01
#
#                 _PANCAN_CNA_PANCAN_K8 _PANCAN_Cluster_Cluster_PANCAN  \
# sampleID
# TCGA-AF-2687-01             COAD-READ                            NaN
# TCGA-AF-2689-01             COAD-READ                   C7-COAD/READ
# TCGA-AF-2689-11                   NaN                   C7-COAD/READ
# TCGA-AF-2690-01             COAD-READ                            NaN
# TCGA-AF-2691-01             COAD-READ                   C7-COAD/READ
#
#                 _PANCAN_DNAMethyl_PANCAN _PANCAN_RPPA_PANCAN_K8  ...  \
# sampleID                                                         ...
# TCGA-AF-2687-01    COADREAD non-CIMP c11                    NaN  ...
# TCGA-AF-2689-01       COADREAD CIMPL c10       COADREAD-like c7  ...
# TCGA-AF-2689-11                      NaN                    NaN  ...
# TCGA-AF-2690-01    COADREAD non-CIMP c11       COADREAD-like c7  ...
# TCGA-AF-2691-01       COADREAD CIMPL c10                    NaN  ...
#
#                 _GENOMIC_ID_TCGA_READ_gistic2 _GENOMIC_ID_TCGA_READ_RPPA_RBN  \
# sampleID
# TCGA-AF-2687-01  TCGA-AF-2687-01A-02D-1732-01                            NaN
# TCGA-AF-2689-01  TCGA-AF-2689-01A-01D-1549-01    TCGA-AF-2689-01A-21-1932-20
# TCGA-AF-2689-11                           NaN                            NaN
# TCGA-AF-2690-01  TCGA-AF-2690-01A-02D-1732-01    TCGA-AF-2690-01A-11-1932-20
# TCGA-AF-2691-01  TCGA-AF-2691-01A-01D-1549-01                            NaN
#
#                 _GENOMIC_ID_data/public/TCGA/READ/miRNA_HiSeq_gene  \
# sampleID
# TCGA-AF-2687-01                                    TCGA-AF-2687-01
# TCGA-AF-2689-01                                                NaN
# TCGA-AF-2689-11                                    TCGA-AF-2689-11
# TCGA-AF-2690-01                                    TCGA-AF-2690-01
# TCGA-AF-2691-01                                                NaN
#
#                 _GENOMIC_ID_TCGA_READ_PDMarray  \
# sampleID
# TCGA-AF-2687-01                            NaN
# TCGA-AF-2689-01                TCGA-AF-2689-01
# TCGA-AF-2689-11                            NaN
# TCGA-AF-2690-01                            NaN
# TCGA-AF-2691-01                TCGA-AF-2691-01
#
#                 _GENOMIC_ID_data/public/TCGA/READ/miRNA_GA_gene  \
# sampleID
# TCGA-AF-2687-01                                             NaN
# TCGA-AF-2689-01                                 TCGA-AF-2689-01
# TCGA-AF-2689-11                                             NaN
# TCGA-AF-2690-01                                             NaN
# TCGA-AF-2691-01                                 TCGA-AF-2691-01
#
#                 _GENOMIC_ID_TCGA_READ_gistic2thd  \
# sampleID
# TCGA-AF-2687-01     TCGA-AF-2687-01A-02D-1732-01
# TCGA-AF-2689-01     TCGA-AF-2689-01A-01D-1549-01
# TCGA-AF-2689-11                              NaN
# TCGA-AF-2690-01     TCGA-AF-2690-01A-02D-1732-01
# TCGA-AF-2691-01     TCGA-AF-2691-01A-01D-1549-01
#
#                   _GENOMIC_ID_TCGA_READ_exp_GAV2_exon  \
# sampleID
# TCGA-AF-2687-01                                   NaN
# TCGA-AF-2689-01                                   NaN
# TCGA-AF-2689-11                                   NaN
# TCGA-AF-2690-01                                   NaN
# TCGA-AF-2691-01  a7fa7e33-58e4-4463-b697-61a9c58bf9e1
#
#                 _GENOMIC_ID_TCGA_READ_mutation_bcm_solid_gene  \
# sampleID
# TCGA-AF-2687-01                                           NaN
# TCGA-AF-2689-01                  TCGA-AF-2689-01A-01W-0831-10
# TCGA-AF-2689-11                                           NaN
# TCGA-AF-2690-01                                           NaN
# TCGA-AF-2691-01                  TCGA-AF-2691-01A-01W-0831-10
#
#                 _GENOMIC_ID_TCGA_READ_exp_HiSeqV2_percentile  \
# sampleID
# TCGA-AF-2687-01         c2a39a12-e882-49aa-a5fa-5356e4bcb823
# TCGA-AF-2689-01                                          NaN
# TCGA-AF-2689-11         a061d300-0dec-42c6-a21c-13af7bba943d
# TCGA-AF-2690-01         dfcfd7e4-4475-4791-a549-c1778db32ae2
# TCGA-AF-2691-01                                          NaN
#
#                 _GENOMIC_ID_TCGA_READ_exp_HiSeqV2_exon
# sampleID
# TCGA-AF-2687-01   c2a39a12-e882-49aa-a5fa-5356e4bcb823
# TCGA-AF-2689-01                                    NaN
# TCGA-AF-2689-11   a061d300-0dec-42c6-a21c-13af7bba943d
# TCGA-AF-2690-01   dfcfd7e4-4475-4791-a549-c1778db32ae2
# TCGA-AF-2691-01                                    NaN
#
# [5 rows x 130 columns]

# %%
# Display gene dataset
gene_data.head()
# Out:
#            TCGA-DC-6156-01  TCGA-DC-6160-01  TCGA-EI-6512-01  TCGA-DC-5869-01  \
# sample
# ARHGEF10L         0.335208         0.452908         1.179008         0.163108
# HIF3A            -1.158126        -2.582626        -0.892726         0.122474
# RNF17            -0.531035        -0.531035        -0.010835        -0.531035
# RNF10            -0.258972        -0.526172         0.336228        -0.787272
# RNF11             0.037722        -1.281078        -1.008778        -0.677478
#
#            TCGA-EI-6507-01  TCGA-AF-3911-01  TCGA-EI-7004-01  TCGA-G5-6572-01  \
# sample
# ARHGEF10L         0.126508         1.096808         0.552108         0.848808
# HIF3A            -0.709026        -1.862026        -1.704726         1.253474
# RNF17            -0.531035        -0.531035        -0.012135        -0.531035
# RNF10             0.390328        -0.286072        -0.143072        -0.321872
# RNF11            -0.478478        -0.849078        -0.265778        -1.116378
#
#            TCGA-EF-5830-01  TCGA-F5-6812-01  ...  TCGA-CI-6620-01  \
# sample                                       ...
# ARHGEF10L         1.359908         1.343608  ...         1.045008
# HIF3A            -1.331526        -0.012826  ...        -2.231326
# RNF17            -0.531035        -0.531035  ...        -0.531035
# RNF10             0.201128         0.697328  ...        -0.383672
# RNF11            -0.650778        -0.207678  ...        -1.284078
#
#            TCGA-AG-3725-01  TCGA-AH-6643-01  TCGA-DY-A0XA-01  TCGA-AF-3400-11  \
# sample
# ARHGEF10L         1.399708         0.491908         0.630708         1.540308
# HIF3A            -4.127526        -3.238526        -2.453226         0.209774
# RNF17            -0.531035        -0.531035        -0.531035        -0.531035
# RNF10             0.253528        -0.152272        -0.458172         0.361228
# RNF11            -0.626878        -0.816678        -1.083878        -0.486878
#
#            TCGA-EI-6506-01  TCGA-AF-2692-11  TCGA-AF-A56K-01  TCGA-DC-6154-01  \
# sample
# ARHGEF10L         1.454808         0.869808         0.855608         1.480208
# HIF3A            -2.553926         2.152274         1.167674         0.547374
# RNF17            -0.531035        -0.531035        -0.531035        -0.531035
# RNF10            -0.265672         0.101328        -0.667272        -0.223772
# RNF11            -0.995878         0.291422        -1.362078        -1.223678
#
#            TCGA-AG-3592-01
# sample
# ARHGEF10L         0.911308
# HIF3A            -0.467126
# RNF17            -0.531035
# RNF10            -0.439072
# RNF11            -1.689478
#
# [5 rows x 105 columns]

# %%
# Set Basic info
gene_fullname = 'APC gene'
gene = 'apc'
condition = 'age'
condition_col = 'days_to_birth'
trait = 'Rectal  Cancer'

# Get the feature dimension of clinical data, and the number of genes
col_offset = len(clinical_data.columns)
num_genes = len(gene_data)
print(f'The clinical dataset has {col_offset} features, and the gene dataset includes {num_genes} genes')
# Out:
# The clinical dataset has 130 features, and the gene dataset includes 20530 genes

# %%
# Merge clinical_data and gene_data on their indices - sample_ID, corresponding to each person
merged_data = clinical_data.join(gene_data.T)
merged_data.head()
# Out:
#                  AWG_MLH1_silencing AWG_cancer_type_Oct62011 CDE_ID_3226963  \
# sampleID
# TCGA-AF-2687-01                 NaN                      NaN            MSS
# TCGA-AF-2689-01                 0.0                   Rectum            MSS
# TCGA-AF-2689-11                 0.0                   Rectum            MSS
# TCGA-AF-2690-01                 NaN                      NaN            MSS
# TCGA-AF-2691-01                 0.0                   Rectum            MSS
#
#                    CIMP MSI_updated_Oct62011     _INTEGRATION  \
# sampleID
# TCGA-AF-2687-01     NaN                  NaN  TCGA-AF-2687-01
# TCGA-AF-2689-01  CIMP.L                  MSS  TCGA-AF-2689-01
# TCGA-AF-2689-11  CIMP.L                  MSS  TCGA-AF-2689-11
# TCGA-AF-2690-01     NaN                  NaN  TCGA-AF-2690-01
# TCGA-AF-2691-01  CIMP.L                  MSS  TCGA-AF-2691-01
#
#                 _PANCAN_CNA_PANCAN_K8 _PANCAN_Cluster_Cluster_PANCAN  \
# sampleID
# TCGA-AF-2687-01             COAD-READ                            NaN
# TCGA-AF-2689-01             COAD-READ                   C7-COAD/READ
# TCGA-AF-2689-11                   NaN                   C7-COAD/READ
# TCGA-AF-2690-01             COAD-READ                            NaN
# TCGA-AF-2691-01             COAD-READ                   C7-COAD/READ
#
#                 _PANCAN_DNAMethyl_PANCAN _PANCAN_RPPA_PANCAN_K8  ...  \
# sampleID                                                         ...
# TCGA-AF-2687-01    COADREAD non-CIMP c11                    NaN  ...
# TCGA-AF-2689-01       COADREAD CIMPL c10       COADREAD-like c7  ...
# TCGA-AF-2689-11                      NaN                    NaN  ...
# TCGA-AF-2690-01    COADREAD non-CIMP c11       COADREAD-like c7  ...
# TCGA-AF-2691-01       COADREAD CIMPL c10                    NaN  ...
#
#                     TULP2     NPY5R     GNGT2    GNGT1     TULP3      PTRF  \
# sampleID
# TCGA-AF-2687-01  0.139722 -1.587117  0.509567  0.85801  0.147323  0.852614
# TCGA-AF-2689-01       NaN       NaN       NaN      NaN       NaN       NaN
# TCGA-AF-2689-11  0.380022  0.167283  0.671867 -1.28139 -0.766577  1.633314
# TCGA-AF-2690-01 -0.200178  1.895983  0.825967 -0.33609 -0.037277  1.156814
# TCGA-AF-2691-01       NaN       NaN       NaN      NaN       NaN       NaN
#
#                     BCL6B     GSTK1      SELP      SELS
# sampleID
# TCGA-AF-2687-01  1.095073 -0.155195  1.547767  0.022788
# TCGA-AF-2689-01       NaN       NaN       NaN       NaN
# TCGA-AF-2689-11 -0.394927  0.398105  1.410667  0.948188
# TCGA-AF-2690-01  1.035173  0.081205  3.199267  0.744988
# TCGA-AF-2691-01       NaN       NaN       NaN       NaN
#
# [5 rows x 20660 columns]

# %%
# Only select relevant columns
input_cols = [condition_col] + merged_data.columns[col_offset: col_offset + num_genes].tolist()
merged_data = merged_data[input_cols]

# Remove sample rows with missing columns.
threshold_rows = 0.8 * len(merged_data)
rows_after_any = len(merged_data.dropna(how='any'))

# Prefer "how='any'", if it does not discard too much data.
if rows_after_any >= threshold_rows:
    merged_data = merged_data.dropna(how='any')
else:
    merged_data = merged_data.dropna(how='all')
    merged_data = merged_data.fillna(0)

merged_data.head()
# Out:
#                  days_to_birth  ARHGEF10L     HIF3A     RNF17     RNF10  \
# sampleID
# TCGA-AF-2687-01       -21098.0   0.410908  2.396474 -0.531035 -0.118372
# TCGA-AF-2689-01       -15082.0   0.000000  0.000000  0.000000  0.000000
# TCGA-AF-2689-11       -15082.0   0.975608  2.391874 -0.531035  0.163828
# TCGA-AF-2690-01       -28119.0   0.378808 -0.220626 -0.531035 -0.416872
# TCGA-AF-2691-01       -17759.0   0.000000  0.000000  0.000000  0.000000
#
#                     RNF11    RNF13   GTF2IP1      REM1     MTVR2  ...  \
# sampleID                                                          ...
# TCGA-AF-2687-01 -0.380378  0.05959 -0.754094  0.778654  0.088301  ...
# TCGA-AF-2689-01  0.000000  0.00000  0.000000  0.000000  0.000000  ...
# TCGA-AF-2689-11 -0.083278 -0.26031 -0.558094  0.834754  0.705501  ...
# TCGA-AF-2690-01 -0.498578  0.44639 -0.800294  2.028054 -0.423399  ...
# TCGA-AF-2691-01  0.000000  0.00000  0.000000  0.000000  0.000000  ...
#
#                     TULP2     NPY5R     GNGT2    GNGT1     TULP3      PTRF  \
# sampleID
# TCGA-AF-2687-01  0.139722 -1.587117  0.509567  0.85801  0.147323  0.852614
# TCGA-AF-2689-01  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# TCGA-AF-2689-11  0.380022  0.167283  0.671867 -1.28139 -0.766577  1.633314
# TCGA-AF-2690-01 -0.200178  1.895983  0.825967 -0.33609 -0.037277  1.156814
# TCGA-AF-2691-01  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
#
#                     BCL6B     GSTK1      SELP      SELS
# sampleID
# TCGA-AF-2687-01  1.095073 -0.155195  1.547767  0.022788
# TCGA-AF-2689-01  0.000000  0.000000  0.000000  0.000000
# TCGA-AF-2689-11 -0.394927  0.398105  1.410667  0.948188
# TCGA-AF-2690-01  1.035173  0.081205  3.199267  0.744988
# TCGA-AF-2691-01  0.000000  0.000000  0.000000  0.000000
#
# [5 rows x 20531 columns]

# %%
# Decode the trait information from Sample IDs. Tumor types range from 01 - 09, normal types from 10 - 19.
# Create a function to check the last two digits of a row index

def mark_tumor(row_index):
    last_two_digits = int(row_index[-2:])
    
    mapping = {
        (1, 9): 1,
        (10, 19): 0
    }
    
    return next((value for (start, end), value in mapping.items() if start <= last_two_digits <= end), -1)


# Use the apply function to add the trait column to merged_data
merged_data[trait] = merged_data.index.to_series().apply(mark_tumor)

merged_data.head()
# Out:
#                  days_to_birth  ARHGEF10L     HIF3A     RNF17     RNF10  \
# sampleID
# TCGA-AF-2687-01       -21098.0   0.410908  2.396474 -0.531035 -0.118372
# TCGA-AF-2689-01       -15082.0   0.000000  0.000000  0.000000  0.000000
# TCGA-AF-2689-11       -15082.0   0.975608  2.391874 -0.531035  0.163828
# TCGA-AF-2690-01       -28119.0   0.378808 -0.220626 -0.531035 -0.416872
# TCGA-AF-2691-01       -17759.0   0.000000  0.000000  0.000000  0.000000
#
#                     RNF11    RNF13   GTF2IP1      REM1     MTVR2  ...  \
# sampleID                                                          ...
# TCGA-AF-2687-01 -0.380378  0.05959 -0.754094  0.778654  0.088301  ...
# TCGA-AF-2689-01  0.000000  0.00000  0.000000  0.000000  0.000000  ...
# TCGA-AF-2689-11 -0.083278 -0.26031 -0.558094  0.834754  0.705501  ...
# TCGA-AF-2690-01 -0.498578  0.44639 -0.800294  2.028054 -0.423399  ...
# TCGA-AF-2691-01  0.000000  0.00000  0.000000  0.000000  0.000000  ...
#
#                     NPY5R     GNGT2    GNGT1     TULP3      PTRF     BCL6B  \
# sampleID
# TCGA-AF-2687-01 -1.587117  0.509567  0.85801  0.147323  0.852614  1.095073
# TCGA-AF-2689-01  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# TCGA-AF-2689-11  0.167283  0.671867 -1.28139 -0.766577  1.633314 -0.394927
# TCGA-AF-2690-01  1.895983  0.825967 -0.33609 -0.037277  1.156814  1.035173
# TCGA-AF-2691-01  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
#
#                     GSTK1      SELP      SELS  Rectal  Cancer
# sampleID
# TCGA-AF-2687-01 -0.155195  1.547767  0.022788               1
# TCGA-AF-2689-01  0.000000  0.000000  0.000000               1
# TCGA-AF-2689-11  0.398105  1.410667  0.948188               0
# TCGA-AF-2690-01  0.081205  3.199267  0.744988               1
# TCGA-AF-2691-01  0.000000  0.000000  0.000000               1
#
# [5 rows x 20532 columns]

# %%
input_cols = merged_data.columns.tolist()
gene_list = [col for col in input_cols if gene in col.lower()]

# %% [markdown]
# ### 2. Preliminary analysis

# %% [markdown]
# Plot the distributions of the target and important regressors

# %%
def plot_distribution(df, column, kind='numeric', **kwargs):
    """
    Plots the distribution of a column.
    
    Args:
    - df (DataFrame): The dataframe containing the data.
    - column (str): The column to plot.
    - kind (str): The type of plot ('numeric' or 'categorical').
    - **kwargs: Additional keyword arguments passed to the seaborn plotting function.
    """
    plt.figure(figsize=(10, 6))
    
    if kind == 'numeric':
        sns.histplot(df[column], kde=True, bins=30, **kwargs)
        plt.ylabel('Frequency')
    elif kind == 'categorical':
        sns.countplot(y=column, data=df, order=df[column].value_counts().index, **kwargs)
        plt.xlabel('Frequency')
        
    plt.title(f'Distribution of {column.capitalize()}')
    plt.show()

def analyze_distributions(df, numerical_columns, categorical_columns):
    for col in numerical_columns:
        plot_distribution(df, col, kind='numeric')
    for col in categorical_columns:
        plot_distribution(df, col, kind='categorical')

# Sample usage:
analyze_distributions(merged_data, numerical_columns=[condition_col, *gene_list], categorical_columns=[trait])

# %% [markdown]
# As can be seen from the histogram of "Days_to_birth", the data are not within the expected range of age.
# This is also indicated by the variable name.

# %%
# Convert "day_to_birth" to age in years
merged_data[condition_col] = (- merged_data[condition_col] / 365.25).astype(int)
merged_data = merged_data.rename(columns={condition_col: condition})
input_cols = merged_data.columns.tolist()

merged_data.head()
# Out:
#                  age  ARHGEF10L     HIF3A     RNF17     RNF10     RNF11  \
# sampleID
# TCGA-AF-2687-01   57   0.410908  2.396474 -0.531035 -0.118372 -0.380378
# TCGA-AF-2689-01   41   0.000000  0.000000  0.000000  0.000000  0.000000
# TCGA-AF-2689-11   41   0.975608  2.391874 -0.531035  0.163828 -0.083278
# TCGA-AF-2690-01   76   0.378808 -0.220626 -0.531035 -0.416872 -0.498578
# TCGA-AF-2691-01   48   0.000000  0.000000  0.000000  0.000000  0.000000
#
#                    RNF13   GTF2IP1      REM1     MTVR2  ...     NPY5R  \
# sampleID                                                ...
# TCGA-AF-2687-01  0.05959 -0.754094  0.778654  0.088301  ... -1.587117
# TCGA-AF-2689-01  0.00000  0.000000  0.000000  0.000000  ...  0.000000
# TCGA-AF-2689-11 -0.26031 -0.558094  0.834754  0.705501  ...  0.167283
# TCGA-AF-2690-01  0.44639 -0.800294  2.028054 -0.423399  ...  1.895983
# TCGA-AF-2691-01  0.00000  0.000000  0.000000  0.000000  ...  0.000000
#
#                     GNGT2    GNGT1     TULP3      PTRF     BCL6B     GSTK1  \
# sampleID
# TCGA-AF-2687-01  0.509567  0.85801  0.147323  0.852614  1.095073 -0.155195
# TCGA-AF-2689-01  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# TCGA-AF-2689-11  0.671867 -1.28139 -0.766577  1.633314 -0.394927  0.398105
# TCGA-AF-2690-01  0.825967 -0.33609 -0.037277  1.156814  1.035173  0.081205
# TCGA-AF-2691-01  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
#
#                      SELP      SELS  Rectal  Cancer
# sampleID
# TCGA-AF-2687-01  1.547767  0.022788               1
# TCGA-AF-2689-01  0.000000  0.000000               1
# TCGA-AF-2689-11  1.410667  0.948188               0
# TCGA-AF-2690-01  3.199267  0.744988               1
# TCGA-AF-2691-01  0.000000  0.000000               1
#
# [5 rows x 20532 columns]

# %% [markdown]
# ### 3. Do regression & Cross Validation

# %%
# Select relevant columns and convert to numpy array
data_array = merged_data.values

# Normalize data
X = data_array
mean = np.mean(X, axis=0)
std = np.std(X, axis=0)
zero_std_columns = np.where(std == 0)[0]
X = (X - mean) / std
X[:, zero_std_columns] = 0

y = merged_data[trait].values

def shuffle_data(X, y):
    """Shuffle data and return shuffled datasets."""
    indices = np.arange(X.shape[0])
    np.random.shuffle(indices)
    return X[indices], y[indices], indices

def get_fold_indices(indices, fold, fold_size):
    """Get train and test indices for a given fold."""
    test_indices = indices[fold*fold_size : (fold+1)*fold_size]
    train_indices = np.setdiff1d(indices, test_indices)
    return train_indices, test_indices

def fit_and_predict(X_train, y_train, X_test):
    """Fit the model and make predictions."""
    var_select = VariableSelection()
    var_select.fit(X_train, y_train)
    return var_select.predict(X_test)

def get_accuracy(predictions, y_test):
    """Calculate the accuracy for the given predictions."""
    binary_predictions = (predictions > 0.5).astype(int)
    return np.mean(binary_predictions == y_test)

def cross_validation(X, y, k=5):
    """Implement k-fold cross-validation."""
    X_shuffled, y_shuffled, indices = shuffle_data(X, y)
    fold_size = len(X) // k
    accuracies = []

    for i in range(k):
        train_indices, test_indices = get_fold_indices(indices, i, fold_size)
        
        X_train, X_test = X_shuffled[train_indices], X_shuffled[test_indices]
        y_train, y_test = y_shuffled[train_indices], y_shuffled[test_indices]
        
        predictions = fit_and_predict(X_train, y_train, X_test)
        accuracy = get_accuracy(predictions, y_test)
        
        accuracies.append(accuracy)

    return np.mean(accuracies)

print(cross_validation(data_array, y))
# Out:
# /var/folders/51/nw17mmq54k17kgt4vfq85xn40000gn/T/ipykernel_1783/1853885604.py:9: RuntimeWarning: invalid value encountered in divide
#   X = (X - mean) / std
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sparse_lmm/helpingMethods.py:49: RuntimeWarning: invalid value encountered in divide
#   ts = beta / np.sqrt(var * sigma)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sparse_lmm/VariableSelection.py:183: RuntimeWarning: divide by zero encountered in log
#   return -np.log(p), np.array(betas)
# 0.8428049671292914

# %%
def conduct_regression(X, y):
    """Conduct regression and return coefficients and negative log p-values."""
    var_select = VariableSelection()
    var_select.fit(X, y)
    coefficients = var_select.getBeta().reshape(-1).tolist()
    nlog_p_values = var_select.getNegLogP().reshape(-1).tolist()
    return coefficients, nlog_p_values

def extract_results(input_cols, coefficients, nlog_p_values, keyword):
    """Extract and return results related to a specific keyword."""
    return [(var, coef, np.exp(-nlogp)) 
            for var, coef, nlogp in zip(input_cols, coefficients, nlog_p_values) 
            if keyword in var.lower()]

def format_results(results, keyword):
    """Format results for a given keyword."""
    report = f"For {keyword}:\n"
    for variable_name, coefficient, p_value in results:
        report += f"{variable_name}: Coefficient = {coefficient}, p-value = {p_value}\n"
    return report

# Conduct regression
coefficients, nlog_p_values = conduct_regression(X, y)

# Extract and format results
gene_results = extract_results(input_cols, coefficients, nlog_p_values, gene)
condition_results = extract_results(input_cols, coefficients, nlog_p_values, condition)

# Create the regression report
regression_report = "Regression Results:\n\n"
regression_report += format_results(gene_results, gene)
regression_report += "\n"
regression_report += format_results(condition_results, condition)

print(regression_report)
# Out:
# Regression Results:
#
# For apc:
# APC: Coefficient = -0.009726602531571413, p-value = 0.9517985670780089
# SNAPC3: Coefficient = 0.0118059441113937, p-value = 0.943952700884608
# APCS: Coefficient = 0.007887408730716666, p-value = 0.9611829320638656
# APC2: Coefficient = -0.021543088942194682, p-value = 0.9102092132323493
# ANAPC1: Coefficient = -0.006825296952504179, p-value = 0.9810889334536357
# ANAPC2: Coefficient = 0.0069017786306346755, p-value = 0.9713571552310675
# ANAPC5: Coefficient = 0.0025528133809506557, p-value = 0.9862179787910867
# ANAPC4: Coefficient = 0.004359759619640239, p-value = 0.9734437313656867
# ANAPC7: Coefficient = 0.007900960953511931, p-value = 0.9645067512570527
# APCDD1L: Coefficient = -0.02432995763060495, p-value = 0.8763221902841682
# ANAPC16: Coefficient = -0.009482309626963031, p-value = 0.9539187276795436
# ANAPC11: Coefficient = 0.004284464814371497, p-value = 0.9830627033318835
# ANAPC10: Coefficient = 0.005322768975261587, p-value = 0.9724132967155539
# ANAPC13: Coefficient = 0.017305608448911592, p-value = 0.9013519005407931
# SNAPC2: Coefficient = -0.0010172289712229807, p-value = 0.9949618569963974
# SNAPC1: Coefficient = 0.017439756752694532, p-value = 0.9386020475978061
# SNAPC5: Coefficient = -0.003964734791098081, p-value = 0.9823478771436892
# SNAPC4: Coefficient = 0.005246952709744793, p-value = 0.9802591199088313
# APCDD1: Coefficient = -0.0011131266057667994, p-value = 0.9941543597865254
#
# For age:
# age: Coefficient = 0.021661471417107146, p-value = 0.32763833929919484
# SAGE1: Coefficient = 0.0043739073623342535, p-value = 0.9727491949901881
# MAGEH1: Coefficient = -0.010968690116262853, p-value = 0.9552730708682432
# GAGE1: Coefficient = 0.007090792044806889, p-value = 0.9569963775355066
# GAGE4: Coefficient = 0.0031443299254350146, p-value = 0.9814547717775951
# GAGE2D: Coefficient = 0.005603268133770693, p-value = 0.9654329805313729
# GAGE2E: Coefficient = 0.053855973765879236, p-value = 0.9283337561457361
# GAGE2C: Coefficient = 0.004524913468387097, p-value = 0.967303616266456
# MAGED1: Coefficient = 0.009782945055688368, p-value = 0.9607603370336357
# MAGED2: Coefficient = 0.002612055140745472, p-value = 0.9881595218967021
# MAGED4: Coefficient = -0.008412711452569959, p-value = 0.9588747328313787
# MAGEA11: Coefficient = -0.00016398029585237936, p-value = 0.9989681269300594
# GAGE12J: Coefficient = 0.0038307918489153135, p-value = 0.9784664619717065
# GAGE12D: Coefficient = -0.0003367725809099659, p-value = 0.9980357687229415
# GAGE12F: Coefficient = 0.05385597376587922, p-value = 0.9283337561457361
# MAGEL2: Coefficient = -0.0006460679602789503, p-value = 0.997322540103211
# MAGEB2: Coefficient = 0.007923886119913445, p-value = 0.948461084713313
# MAGEB3: Coefficient = 0.003005652869436304, p-value = 0.9822603168476611
# MAGEB1: Coefficient = 0.0017142689907753614, p-value = 0.9900081047326179
# MAGEB4: Coefficient = -0.0011921586191937818, p-value = 0.99297103548143
# PAGE3: Coefficient = 0.05385597376588873, p-value = 0.9283337561457236
# MAGEB16: Coefficient = -0.004537224333635058, p-value = 0.972539566229476
# MAGEB6: Coefficient = 0.005942625638099934, p-value = 0.9672026092547935
# XAGE1D: Coefficient = 0.006635562242111601, p-value = 0.9625638951322144
# BAGE: Coefficient = 0.00023762749965275387, p-value = 0.9986763496404331
# PAGE2B: Coefficient = 0.002286592325253893, p-value = 0.9857078950788214
# RAGE: Coefficient = -0.006829096456402013, p-value = 0.9679908587617889
# MAGEA9B: Coefficient = 0.004640181231429266, p-value = 0.9690871218098034
# MAGED4B: Coefficient = -0.009143310877539656, p-value = 0.9599360854848396
# AGER: Coefficient = -0.0048737169958759175, p-value = 0.9832865032502659
# MAGEA12: Coefficient = 0.016369425298736587, p-value = 0.9046242724975093
# MAGEA10: Coefficient = 0.004083830085051599, p-value = 0.9748386750388573
# GAGE2A: Coefficient = -0.0029261564298973318, p-value = 0.9817756373748344
# GAGE2B: Coefficient = 0.0044375231344395685, p-value = 0.9687319590173713
# GAGE8: Coefficient = -0.004491513668216845, p-value = 0.974132229474222
# CAGE1: Coefficient = 0.010945608730752548, p-value = 0.9163364541941537
# MAGEE2: Coefficient = -0.026792727198167055, p-value = 0.8934175244411693
# MAGEE1: Coefficient = 0.0028175249981265468, p-value = 0.9863767376842516
# PAGE4: Coefficient = 0.0007842349840755428, p-value = 0.9945788227203447
# PAGE5: Coefficient = -0.005103653152380216, p-value = 0.9670018150895607
# PAGE2: Coefficient = 0.001446176287064789, p-value = 0.991101898863008
# PAGE1: Coefficient = 0.007698266548296246, p-value = 0.9570696075329037
# MAGEC1: Coefficient = 0.003598698339456547, p-value = 0.9799251300475667
# MAGEC3: Coefficient = 0.019965714490082456, p-value = 0.9269575284573763
# MAGEC2: Coefficient = 0.00458367247425834, p-value = 0.9720342456401924
# GAGE10: Coefficient = 0.053855973765884926, p-value = 0.9283337561457286
# GAGE13: Coefficient = 0.05385597376587922, p-value = 0.9283337561457361
# MAGEA8: Coefficient = 0.017713251697475063, p-value = 0.8881675533463441
# MAGEA3: Coefficient = 0.014637991789140537, p-value = 0.9169695751158876
# MAGEA2: Coefficient = 0.014931827547094541, p-value = 0.9169127618167006
# MAGEA1: Coefficient = 0.005953850522776939, p-value = 0.970956918235323
# MAGEA6: Coefficient = 0.015610669451578891, p-value = 0.9100571327123463
# MAGEA5: Coefficient = 0.0077680783223577216, p-value = 0.9539700366044772
# MAGEA4: Coefficient = 0.0022375955363995227, p-value = 0.9855626018690179
# MAGEF1: Coefficient = 0.006743825735252928, p-value = 0.9637793987273793
# MAGEB18: Coefficient = -0.0033980688054640633, p-value = 0.9768396855230734
# MAGEB10: Coefficient = -0.004598887183904192, p-value = 0.9730682605331014
# CTAGE9: Coefficient = -0.00811138906783024, p-value = 0.9569466444649384
# CTAGE1: Coefficient = 0.001423321046983686, p-value = 0.9915397069020305
# CTAGE4: Coefficient = -0.005584098705304316, p-value = 0.970969340899511
# CTAGE5: Coefficient = 0.0017655317959678104, p-value = 0.9919964711298119
# CTAGE6: Coefficient = -0.005912569794575594, p-value = 0.9615530653455777
# BAGE2: Coefficient = -0.00773878905202995, p-value = 0.9520736894019384
# XAGE5: Coefficient = -0.004153298532918494, p-value = 0.9755312389364192
# XAGE3: Coefficient = 0.006838620918320849, p-value = 0.9503162726555685
# LAGE3: Coefficient = 0.01623742699240368, p-value = 0.9362854940207084
# XAGE2: Coefficient = 0.007385821606329802, p-value = 0.950250291902754

# %% [markdown]
# ### 4. Discussion

# %%
# Generate hypothesis text

hypotheses_text = f'Hypothesis\n\n'
hypotheses_text += f'For the question "What is the relationship between {gene_fullname} and {trait} when considering the influence of {condition}?", the following hypotheses can be proposed:\n\n'
hypotheses_text += f'Null Hypothesis (H0): There is no significant association between the expression of the {gene_fullname} and {trait} when considering the influence of {condition}.\n\n'
hypotheses_text += f'Alternative Hypothesis (H1): There is an association between the expression of the {gene_fullname} and {trait} when considering the influence of {condition}.\n\n'

print(hypotheses_text)
# Out:
# Hypothesis
#
# For the question "What is the relationship between APC gene and Rectal  Cancer when considering the influence of age?", the following hypotheses can be proposed:
#
# Null Hypothesis (H0): There is no significant association between the expression of the APC gene and Rectal  Cancer when considering the influence of age.
#
# Alternative Hypothesis (H1): There is an association between the expression of the APC gene and Rectal  Cancer when considering the influence of age.

# %%
threshold = 0.05
def interpret_coefficient(variable_name, coefficient, p_value, significance_level=0.05):
    """Interpret the coefficient and p-value of a variable."""
    coef_message = {
        coefficient > 0: "positive",
        coefficient < 0: "negative"
    }.get(True, "zero")
    
    significance_message = "statistically significant" if p_value < significance_level else "not statistically significant"

    interpretation = (
        f"Variable: {variable_name}\n"
        f"Coefficient is {coef_message}, "
        f"and it is {significance_message} (p-value {'<' if p_value < significance_level else '>='} {significance_level}).\n\n"
    )

    return interpretation

# Create a report to interpret coefficients and p-values for all variables
interpretations = [
    interpret_coefficient(variable_name, coefficient, p_value, threshold)
    for variable_name, coefficient, p_value in gene_results + condition_results
]

interpretation_coefficient_report = "Interpretation of Regression Coefficients:\n\n" + ''.join(interpretations)

print(interpretation_coefficient_report)
# Out:
# Interpretation of Regression Coefficients:
#
# Variable: APC
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: SNAPC3
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: APCS
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: APC2
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: ANAPC1
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: ANAPC2
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: ANAPC5
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: ANAPC4
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: ANAPC7
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: APCDD1L
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: ANAPC16
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: ANAPC11
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: ANAPC10
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: ANAPC13
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: SNAPC2
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: SNAPC1
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: SNAPC5
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: SNAPC4
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: APCDD1
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: age
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: SAGE1
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEH1
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE1
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE4
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE2D
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE2E
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE2C
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGED1
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGED2
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGED4
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEA11
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE12J
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE12D
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE12F
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEL2
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEB2
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEB3
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEB1
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEB4
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: PAGE3
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEB16
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEB6
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: XAGE1D
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: BAGE
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: PAGE2B
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: RAGE
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEA9B
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGED4B
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: AGER
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEA12
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEA10
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE2A
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE2B
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE8
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: CAGE1
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEE2
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEE1
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: PAGE4
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: PAGE5
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: PAGE2
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: PAGE1
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEC1
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEC3
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEC2
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE10
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: GAGE13
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEA8
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEA3
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEA2
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEA1
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEA6
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEA5
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEA4
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEF1
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEB18
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: MAGEB10
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: CTAGE9
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: CTAGE1
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: CTAGE4
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: CTAGE5
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: CTAGE6
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: BAGE2
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: XAGE5
# Coefficient is negative, and it is not statistically significant (p-value >= 0.05).
#
# Variable: XAGE3
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: LAGE3
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).
#
# Variable: XAGE2
# Coefficient is positive, and it is not statistically significant (p-value >= 0.05).

# %%
def confirm_hypothesis(coefficient, p_value, variable_name, significance_level=0.05):
    """Determine if H0 or H1 is confirmed based on coefficient and p-value."""
    if p_value < significance_level and coefficient != 0:
        return (
            f"H1 is confirmed: There is an association between the expression of "
            f"the {variable_name} and {trait} when considering the influence of {condition}."
        )
    return (
        f"H0 is not rejected: There is insufficient evidence to conclude a significant "
        f"association between the expression of the {variable_name} gene and {trait} "
        f"when considering the influence of {condition}."
    )

# Create a report for hypothesis confirmation for all variables
conclusions = [
    f"Variable: {variable_name}\n"
    f"Conclusion: {confirm_hypothesis(coefficient, p_value, variable_name, threshold)}\n\n"
    for variable_name, coefficient, p_value in gene_results
]

hypothesis_confirmation_report = "Hypothesis Confirmation and Conclusion:\n\n" + ''.join(conclusions)

print(hypothesis_confirmation_report)
# Out:
# Hypothesis Confirmation and Conclusion:
#
# Variable: APC
# Conclusion: H0 is not rejected: There is insufficient evidence to conclude a significant association between the expression of the APC gene and Rectal  Cancer when considering the influence of age.
#
# Variable: SNAPC3
# Conclusion: H0 is not rejected: There is insufficient evidence to conclude a significant association between the expression of the SNAPC3 gene and Rectal  Cancer when considering the influence of age.
#
# Variable: APCS
# Conclusion: H0 is not rejected: There is insufficient evidence to conclude a significant association between the expression of the APCS gene and Rectal  Cancer when considering the influence of age.
#
# Variable: APC2
# Conclusion: H0 is not rejected: There is insufficient evidence to conclude a significant association between the expression of the APC2 gene and Rectal  Cancer when considering the influence of age.
#
# Variable: ANAPC1
# Conclusion: H0 is not rejected: There is insufficient evidence to conclude a significant association between the expression of the ANAPC1 gene and Rectal  Cancer when considering the influence of age.
#
# Variable: ANAPC2
# Conclusion: H0 is not rejected: There is insufficient evidence to conclude a significant association between the expression of the ANAPC2 gene and Rectal  Cancer when considering the influence of age.
#
# Variable: ANAPC5
# Conclusion: H0 is not rejected: There is insufficient evidence to conclude a significant association between the expression of the ANAPC5 gene and Rectal  Cancer when considering the influence of age.
#
# Variable: ANAPC4
# Conclusion: H0 is not rejected: There is insufficient evidence to conclude a significant association between the expression of the ANAPC4 gene and Rectal  Cancer when considering the influence of age.
#
# Variable: ANAPC7
# Conclusion: H0 is not rejected: There is insufficient evidence to conclude a significant association between the expression of the ANAPC7 gene and Rectal  Cancer when considering the influence of age.
#
# Variable: APCDD1L
# Conclusion: H0 is not rejected: There is insufficient evidence to conclude a significant association between the expression of the APCDD1L gene and Rectal  Cancer when considering the influence of age.
#
# Variable: ANAPC16
# Conclusion: H0 is not rejected: There is insufficient evidence to conclude a significant association between the expression of the ANAPC16 gene and Rectal  Cancer when considering the influence of age.
#
# Variable: ANAPC11
# Conclusion: H0 is not rejected: There is insufficient evidence to conclude a significant association between the expression of the ANAPC11 gene and Rectal  Cancer when considering the influence of age.
#
# Variable: ANAPC10
# Conclusion: H0 is not rejected: There is insufficient evidence to conclude a significant association between the expression of the ANAPC10 gene and Rectal  Cancer when considering the influence of age.
#
# Variable: ANAPC13
# Conclusion: H0 is not rejected: There is insufficient evidence to conclude a significant association between the expression of the ANAPC13 gene and Rectal  Cancer when considering the influence of age.
#
# Variable: SNAPC2
# Conclusion: H0 is not rejected: There is insufficient evidence to conclude a significant association between the expression of the SNAPC2 gene and Rectal  Cancer when considering the influence of age.
#
# Variable: SNAPC1
# Conclusion: H0 is not rejected: There is insufficient evidence to conclude a significant association between the expression of the SNAPC1 gene and Rectal  Cancer when considering the influence of age.
#
# Variable: SNAPC5
# Conclusion: H0 is not rejected: There is insufficient evidence to conclude a significant association between the expression of the SNAPC5 gene and Rectal  Cancer when considering the influence of age.
#
# Variable: SNAPC4
# Conclusion: H0 is not rejected: There is insufficient evidence to conclude a significant association between the expression of the SNAPC4 gene and Rectal  Cancer when considering the influence of age.
#
# Variable: APCDD1
# Conclusion: H0 is not rejected: There is insufficient evidence to conclude a significant association between the expression of the APCDD1 gene and Rectal  Cancer when considering the influence of age.
